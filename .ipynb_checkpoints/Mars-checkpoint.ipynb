# %%
from splinter import Browser
from bs4 import BeautifulSoup
import time
import pymongo
import requests
from splinter.exceptions import ElementDoesNotExist

# %%
executable_path = {"executable_path": "chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)

# %%
url = 'https://mars.nasa.gov/news/'
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
results = soup.find_all("div", class_="content_title")
for result in results:

    title = result.find('a').text
  
    link = result.a['href']
    paragraph=soup.find("div", class_="article_teaser_body").text
    if (title and paragraph and link):
        print('------------')
        print("News Title = ", title, "\n")
        print("News Summary", paragraph, "\n")
        print(link, "\n")
# Out:
# ------------
# News Title =  InSight Is the Newest Mars Weather Service
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8415/insight-is-the-newest-mars-weather-service/
#
# ------------
# News Title =  Six Things to Know About NASA's Opportunity Rover
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8414/six-things-to-know-about-nasas-opportunity-rover/
#
# ------------
# News Title =  NASA's Opportunity Rover Mission on Mars Comes to End
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8413/nasas-opportunity-rover-mission-on-mars-comes-to-end/
#
# ------------
# News Title =  NASA's InSight Prepares to Take Mars' Temperature
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8412/nasas-insight-prepares-to-take-mars-temperature/
#
# ------------
# News Title =  NASA to Share Results of Effort to Recover Mars Rover
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8411/nasa-to-share-results-of-effort-to-recover-mars-rover/
#
# ------------
# News Title =  NASA's MAVEN Spacecraft Shrinking its Mars Orbit to Prepare for Mars 2020 Rover
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8410/nasas-maven-spacecraft-shrinking-its-mars-orbit-to-prepare-for-mars-2020-rover/
#
# ------------
# News Title =  360 Video: Curiosity Rover Departs Vera Rubin Ridge
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8409/360-video-curiosity-rover-departs-vera-rubin-ridge/
#
# ------------
# News Title =  Beyond Mars, the Mini MarCO Spacecraft Fall Silent
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8408/beyond-mars-the-mini-marco-spacecraft-fall-silent/
#
# ------------
# News Title =  InSight's Seismometer Now Has a Cozy Shelter on Mars
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8407/insights-seismometer-now-has-a-cozy-shelter-on-mars/
#
# ------------
# News Title =  "Mars Buggy" Curiosity Measures a Mountain's Gravity
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8406/mars-buggy-curiosity-measures-a-mountains-gravity/
#
# ------------
# News Title =  Curiosity Says Farewell to Mars' Vera Rubin Ridge
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8405/curiosity-says-farewell-to-mars-vera-rubin-ridge/
#
# ------------
# News Title =  Rover Team Beaming New Commands to Opportunity on Mars
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8404/rover-team-beaming-new-commands-to-opportunity-on-mars/
#
# ------------
# News Title =  NASA's Opportunity Rover Logs 15 Years on Mars
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8403/nasas-opportunity-rover-logs-15-years-on-mars/
#
# ------------
# News Title =  NASA's InSight Places First Instrument on Mars
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8402/nasas-insight-places-first-instrument-on-mars/
#
# ------------
# News Title =  InSight Engineers Have Made a Martian Rock Garden
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8401/insight-engineers-have-made-a-martian-rock-garden/
#
# ------------
# News Title =  Mars InSight Lander Seen in First Images from Space
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8400/mars-insight-lander-seen-in-first-images-from-space/
#
# ------------
# News Title =  NASA's InSight Takes Its First Selfie
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8398/nasas-insight-takes-its-first-selfie/
#
# ------------
# News Title =  NASA InSight Lander 'Hears' Martian Winds
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8397/nasa-insight-lander-hears-martian-winds/
#
# ------------
# News Title =  NASA's Mars InSight Flexes Its Arm
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8396/nasas-mars-insight-flexes-its-arm/
#
# ------------
# News Title =  Mars New Home 'a Large Sandbox'
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8395/mars-new-home-a-large-sandbox/
#
# ------------
# News Title =  NASA Hears MarCO CubeSats Loud and Clear from Mars
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8394/nasa-hears-marco-cubesats-loud-and-clear-from-mars/
#
# ------------
# News Title =  InSight Is Catching Rays on Mars
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8393/insight-is-catching-rays-on-mars/
#
# ------------
# News Title =  NASA InSight Lander Arrives on Martian Surface
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8392/nasa-insight-lander-arrives-on-martian-surface/
#
# ------------
# News Title =  Landing Day for InSight
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8391/landing-day-for-insight/
#
# ------------
# News Title =  NASA InSight Landing on Mars: Milestones
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8390/nasa-insight-landing-on-mars-milestones/
#
# ------------
# News Title =  NASA InSight Team on Course for Mars Touchdown
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8389/nasa-insight-team-on-course-for-mars-touchdown/
#
# ------------
# News Title =  What Two Planetary Siblings Can Teach Us About Life
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8388/what-two-planetary-siblings-can-teach-us-about-life/
#
# ------------
# News Title =  NASA Announces Landing Site for Mars 2020 Rover
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8387/nasa-announces-landing-site-for-mars-2020-rover/
#
# ------------
# News Title =  NASA to Host Media Call on Next Mars Landing Site
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8386/nasa-to-host-media-call-on-next-mars-landing-site/
#
# ------------
# News Title =  How NASA Will Know When InSight Touches Down
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8385/how-nasa-will-know-when-insight-touches-down/
#
# ------------
# News Title =  NASA Brings Mars Landing to Viewers Everywhere
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8384/nasa-brings-mars-landing-to-viewers-everywhere/
#
# ------------
# News Title =  Curiosity on the Move Again
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8371/curiosity-on-the-move-again/
#
# ------------
# News Title =  The Mars InSight Landing Site Is Just Plain Perfect
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8383/the-mars-insight-landing-site-is-just-plain-perfect/
#
# ------------
# News Title =  Five Things to Know About InSight's Mars Landing
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8382/five-things-to-know-about-insights-mars-landing/
#
# ------------
# News Title =  NASA Launches a New Podcast to Mars
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8381/nasa-launches-a-new-podcast-to-mars/
#
# ------------
# News Title =  Update on Opportunity Rover Recovery Efforts
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8364/update-on-opportunity-rover-recovery-efforts/
#
# ------------
# News Title =  Third ASPIRE Test Confirms Mars 2020 Parachute a Go
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8380/third-aspire-test-confirms-mars-2020-parachute-a-go/
#
# ------------
# News Title =  NASA to Host Briefing on November Mars InSight Landing
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8379/nasa-to-host-briefing-on-november-mars-insight-landing/
#
# ------------
# News Title =  NASA's InSight Will Study Mars While Standing Still
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8378/nasas-insight-will-study-mars-while-standing-still/
#
# ------------
# News Title =  NASA's First Image of Mars from a CubeSat
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8377/nasas-first-image-of-mars-from-a-cubesat/
#
# ------------
# News Title =
# Opportunity Hunkers Down During Dust Storm
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8348/opportunity-hunkers-down-during-dust-storm/
#
# ------------
# News Title =
# NASA Finds Ancient Organic Material, Mysterious Methane on Mars
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8347/nasa-finds-ancient-organic-material-mysterious-methane-on-mars/
#
# ------------
# News Title =
# NASA Invests in Visionary Technology
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8326/nasa-invests-in-visionary-technology/
#
# ------------
# News Title =
# NASA's Opportunity Rover Mission on Mars Comes to End
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8413/nasas-opportunity-rover-mission-on-mars-comes-to-end/
#
# ------------
# News Title =
# NASA's InSight Places First Instrument on Mars
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8402/nasas-insight-places-first-instrument-on-mars/
#
# ------------
# News Title =
# NASA Announces Landing Site for Mars 2020 Rover
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8387/nasa-announces-landing-site-for-mars-2020-rover/
#
# ------------
# News Title =
# Opportunity Hunkers Down During Dust Storm
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8348/opportunity-hunkers-down-during-dust-storm/
#
# ------------
# News Title =
# NASA Finds Ancient Organic Material, Mysterious Methane on Mars
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8347/nasa-finds-ancient-organic-material-mysterious-methane-on-mars/
#
# ------------
# News Title =
# NASA Invests in Visionary Technology
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8326/nasa-invests-in-visionary-technology/
#
# ------------
# News Title =
# NASA's Opportunity Rover Mission on Mars Comes to End
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8413/nasas-opportunity-rover-mission-on-mars-comes-to-end/
#
# ------------
# News Title =
# NASA's InSight Places First Instrument on Mars
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8402/nasas-insight-places-first-instrument-on-mars/
#
# ------------
# News Title =
# NASA Announces Landing Site for Mars 2020 Rover
#
#
# News Summary By collecting data around the clock, NASA's lander will provide unique science about the Martian surface.
#
# /news/8387/nasa-announces-landing-site-for-mars-2020-rover/

# %%
#I used Splinter as the assignment dictated in the boxes below
# however I was was able to pull the link for the featured image with BS from home page
# so I included that too, in this box
url_pic = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
browser.visit(url_pic)
html_pic = browser.html
soup_pic = BeautifulSoup(html_pic, 'html.parser')

# %%
results1 = soup_pic.find('a', class_="button fancybox")['data-fancybox-href']
featured_image_url=("https://www.jpl.nasa.gov"+results1)
print(featured_image_url)
# Out:
# https://www.jpl.nasa.gov/spaceimages/images/mediumsize/PIA18816_ip.jpg

# %%
#Now to get splinter results which were the same end result
browser.click_link_by_partial_text('FULL')

html_f_pic = browser.html
soup_f_pic= BeautifulSoup(html_f_pic, 'html.parser')

# %%
results2 = soup_f_pic.find('img src', class_="fancybox-image")
featured_image_url1=("https://www.jpl.nasa.gov"+results1)
print(featured_image_url1)
# Out:
# https://www.jpl.nasa.gov/spaceimages/images/mediumsize/PIA18816_ip.jpg
